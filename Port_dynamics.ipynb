# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


fig = plt.figure(figsize = (25, 15))
data = np.load('results/x_arr.npy')
data
sns.heatmap(data.T, cmap = sns.cm.rocket_r)
# sns.heatmap(data.T, cmap = "Greys")
# Out:
# <AxesSubplot:>
